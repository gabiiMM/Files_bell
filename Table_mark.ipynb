# %% [markdown]
# <table>
#   <thead>
#     <tr style="background-color: DarkSlateGray; color: white;">
#       <th>Type</th>
#       <th>Species</th>
#       <th>Name</th>
#       <th>Raw data</th>
#       <th>Deduper</th>
#       <th>Trimm</th>
#       <th>Bridge</th>
#       <th>Valid reads</th>
#     </tr>
#     <tr style="background-color: mediumspringgreen; color: black;">
#       <td>Shoot</td>
#       <td>A. thaliana</td>
#       <td>KO186</td>
#       <td>202,232,997 | <b>100 %</b></td>
#       <td>78,027,454 | <b>38.58 %</b></td>
#       <td>57,758,113 | <b>28.56 %</b></td>
#       <td>F -> 26,614,540 | <b>13.16 %</b> <br> R -> 24,774,831 | <b>12.25 %</b> </td>
#       <td>F -> 10,318,184 | <b>5.10 %</b> <br> R -> 9,920,878 | <b>4.91 %</b></td>
#     </tr>
#   </thead>
#   <tbody>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>B. oleracea</td>
#       <td>KO187</td>
#       <td>289,753,559 | <b> 100 % </b></td>
#       <td>49,726,063 | <b> 17.16 % </b></td>
#       <td>38,622,033 | <b> 13.33 %</b></td>
#       <td>F -> 9,629,135 | <b style="color: darkred;"> 3.32 % </b> <br> R -> 8,182,550 | <b style="color: darkred;"> 2.82 % </b></td>
#       <td>F -> 4,365,159 | <b style="color: darkred;"> 1.51 % </b> <br> R -> 4,064,553 | <b style="color: darkred;"> 1.40 % </b></td>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>B. oleracea</td>
#       <td>KO188</td>
#       <td>277,155,216 | <b> 100 % </b></td>
#       <td>61,346,251 | <b> 22.13 % </b></td>
#       <td>38,311,754 | <b> 13.82 %</td>
#       <td>F -> 16,265,206 | <b> 5.87 % </b> <br> R -> 15,406,143 | <b> 5.56 % </b></td>
#       <td>F -> 10,378,367 | <b> 3.74 % </b> <br> R -> 10,057,572 | <b> 3.63 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>B. oleracea</td>
#       <td>KO189</td>
#       <td>232,225,737 | <b> 100 % </b></td>
#       <td>52,001,057 | <b> 22.39 % </b></td>
#       <td>38,009,107 | <b> 16.37 % </b></td>
#       <td>F -> 16,109,689 | <b style="color:darkred"> 6.94 % </b> <br> R -> 13,267,537 | <b style="color:darkred"> 5.71 %</b></td>
#       <td>F -> 4,374,365 | <b style="color:darkred"> 1.88% </b> <br> R -> 3,837,617 | <b style="color:darkred"> 1.65 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>B. oleracea</td>
#       <td>KO190</td>
#       <td>249,315,267 | <b> 100 % </b></td>
#       <td>87,552,575 | <b> 35.12 % </b></td>
#       <td>62,597,930 | <b> 25.11% </b></td>
#       <td>F -> 29,121,954 | <b> 11.68 % </b> <br> R -> 25,222,652 | <b> 10.12 % </b></td>
#       <td>F -> 10,332,495 | <b> 4.14 % </b> <br> R -> 9,297,819 | <b> 3.73 % </b></td>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>S. parvulla</td>
#       <td>KO191</td>
#       <td>231,006,443 | <b> 100 % <b></td>
#       <td>106,994,588 | <b> 46.32 % </b></td>
#       <td>87,849,987 | <b> 38.03 % </b></td>
#       <td>F -> 42,420,907 | <b> 18.37 % </b> <br> R -> 39,284,715 | <b>17.01 % </b></td>
#       <td>F -> 10,857,241 | <b> 4.70 % </b> <br> R -> 9,828,638 | <b> 4.25 % </b></td>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>S. parvulla</td>
#       <td>KO192</td>
#       <td>232,496,947 | <b> 100 % </b></td>
#       <td>149,017,310 | <b> 64.09 % </b></td>
#       <td>48,592,821 | <b> 20.90 % </b></td>
#       <td>F -> 28,497,761 | <b>12.26 % </b> <br> R -> 27,662,338 | <b> 11.90 % </b></td>
#       <td>F -> 10,698,822 | <b> 4.60 % </b> <br> R -> 10,584,949 | <b> 4.55 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>S. parvulla</td>
#       <td>KO193</td>
#       <td>201,778,836 | <b> 100 % </b></td>
#       <td>68,582,959 | <b> 33.99 % </b></td>
#       <td>44,853,798 | <b> 22.23 % </b></td>
#       <td>F -> 24,993,626 | <b> 12.39 % </b> <br> R -> 22,614,029 | <b> 11.21 % </b></td>
#       <td>F -> 7,343,432 | <b> 3.64 % </b> <br> R -> 7,085,863 | <b> 3.51 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>S. parvulla</td>
#       <td>KO194</td>
#       <td>240,537,070 | <b> 100 % </b></td>
#       <td>62,485,482 | <b> 25.98 % </b></td>
#       <td>44,704,669 | <b> 18.59 % </b></td>
#       <td>F -> 5,091,465 | <b style="color:darkred"> 2.12 % </b> <br> R -> 4,665,162 | <b style="color:darkred"> 1.94 % </b></td>
#       <td>F -> 2,288,225 | <b style="color:darkred"> 0.95 % </b> <br> R -> 2,137,248 | <b style="color:darkred"> 0.89 % </b></td>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>C. rubella</td>
#       <td>KO195</td>
#       <td>303,730,056 | <b> 100 % </b></td>
#       <td>193,024,045 | <b> 63.55 % </b></td>
#       <td>73,523,907 | <b> 24.21 % </b></td>
#       <td>F -> 40,997,432 | <b> 13.50 % </b> <br> R -> 40,274,220 | <b> 13.26 % </b></td>
#       <td>F -> 16,645,439 | <b> 5.48 % </b> <br> R -> 16,540,905 | <b> 5.45 % </b></td>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>C. rubella</td>
#       <td>KO196</td>
#       <td>253,912,236 | <b> 100 % </b></td>
#       <td>73,200,194 | <b> 28.23 % </b></td>
#       <td>61,310,177 | <b> 24.15 % </b></td>
#       <td>F -> 23,325,211 | <b> 9.19 % </b> <br> R -> 21,662,924 | <b> 8.53 % </b></td>
#       <td>F -> 13,610,318 | <b> 5.36 % </b> <br> R -> 13,117,958 | <b> 5.17 % </b></td>
#         </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>C. rubella</td>
#       <td>KO197</td>
#       <td>163,542,237 | <b> 100 % </b></td>
#       <td>33,661,294 | <b> 20.58 % </b></td>
#       <td>29,254,534 | <b> 17.89 % </b></td>
#       <td>F -> 8,477,400 | <b style="color:darkred"> 5.18 % </b> <br> R -> 8,122,297 | <b style="color:darkred"> 4.97 % </b></td>
#       <td>F -> 4,217,460 | <b style="color:darkred"> 2.58 % </b> <br> R -> 4,057,662 | <b style="color:darkred"> 2.48 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>C. rubella</td>
#       <td>KO198</td>
#       <td>184,020,162 | <b> 100 % </b></td>
#       <td>50,110,560 | <b> 27.23 % </b></td>
#       <td>40,511,739 | <b> 22.01 % </b></td>
#       <td>F -> 1,067,759 | <b style="color:darkred"> 0.58 % </b> <br> R -> 1,014,832 | <b style="color:darkred"> 0.55 % </b></td>
#       <td>F -> 525,608 | <b style="color:darkred"> 0.29 % </b> <br> R -> 492,816 | <b style="color:darkred"> 0.27 % </b></td>
#     <tr style="background-color: DarkSlateGray; color: white;">
#       <th>Type</th>
#       <th>Species</th>
#       <th>Name</th>
#       <th>Raw data</th>
#       <th>Deduper</th>
#       <th>Trimm</th>
#       <th>Bridge</th>
#       <th>Valid reads</th>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>A. thaliana</td>
#       <td>KO100</td>
#       <td>253,057,121 | <b> 100 % </b></td>
#       <td>54,960,441 | <b> 21.72 % </b></td>
#       <td>53,857,022 | <b> 21.28 % </b></td>
#       <td><b> --- </b></td>
#       <td>17,049,329 | <b> 6.74 % </b></td>
#     </tr>
#     <tr style="background-color: mediumaquamarine; color: black;">
#       <td>Shoot</td>
#       <td>A. thaliana</td>
#       <td>KO101</td>
#       <td>362,164,965 | <b> 100 % </b></td>
#       <td>191,393,951 | <b> 52.84 % </b></td>
#       <td>175,510,462 | <b> 48.46 % </b></td>
#       <td><b> ---</b></td>
#       <td>39,118,189 | <b> 10.80 % </b></td>
#         </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>A. thaliana</td>
#       <td>KO102</td>
#       <td>209,909,826 | <b> 100 % </b></td>
#       <td>48,161,313 | <b> 22.94 % </b></td>
#       <td>47,572,971 | <b> 22.66 % % </b></td>
#       <td><b> --- </b></td>
#       <td>15,698,498 | <b> 7.48 % </b></td>
#     </tr>
#     <tr style="background-color: peru; color: black;">
#       <td>Root</td>
#       <td>A. thaliana</td>
#       <td>KO103</td>
#       <td>126,774,406 | <b> 100 % </b></td>
#       <td>42,367,550 | <b> 33.42 % </b></td>
#       <td>41,505,895| <b> 32.74% </b></td>
#       <td><b> ---</b></td>
#       <td>11,867,168 | <b> 9.36 % </b></td>

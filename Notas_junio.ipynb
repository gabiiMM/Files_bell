# %% [markdown]
# ## Greenscreen

# %% [markdown]
# El repositorio de Github:
# **https://github.com/sklasfeld/GreenscreenProject**

# %% [markdown]
# To generate a demo greenscreen at path demo/data/macs2_out/inputControls/qval10/merge500bp_20inputs.txt
# run the following command in the current working directory:
# python3 scripts/greenscreenPipeline.py \
#     -c Chr2 --genome_prefix TAIR10_Chr2 \
#     --trimmomatic_params "LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36" \
#     --bowtie2_index_dir demo/meta/ArabidopsisGenome/bowtie2_genome_dir \
#     --chipqc_samplesheet_dir  demo/meta \
#     demo/meta/input_meta.csv \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2.fasta \
#     demo/meta/ArabidopsisGenome/Araport11_GFF3_genes_transposons.UPDATED.201606.Chr2.gff \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2_count.txt \
#     demo/data

# %% [markdown]
# Instalar **git** & **docker** y clonar el repo de GreenscreenProject.
# Descargar la imagen con docker.
# Correr y generar un ambiente interactivo en docker.

# %% [markdown]
# Este es el comando de prueba:

# %% [markdown]
# python3 scripts/greenscreenPipeline.py \
#     -c Chr2 --genome_prefix TAIR10_Chr2 \
#     --trimmomatic_params "LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36" \
#     --bowtie2_index_dir demo/meta/ArabidopsisGenome/bowtie2_genome_dir \
#     --chipqc_samplesheet_dir  demo/meta \
#     demo/meta/input_meta.csv \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2.fasta \
#     demo/meta/ArabidopsisGenome/Araport11_GFF3_genes_transposons.UPDATED.201606.Chr2.gff \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2_count.txt \
#     demo/data

# %% [markdown]
# Estos son los parametros que se pueden modificar del script:
# python3 scripts/greenscreenPipeline.py --help
#
# usage: greenscreenPipeline.py
# [-h] [-ta ADAPTER_F] [-tm SEED_MISMATCHES] [-tp PALINDROM_CLIP_THRESHOLD] [-ts SIMPLE_CLIP_THRESHOLD]
# [-t TRIMMOMATIC_PARAMS] [-c CHROMOSOMES [CHROMOSOMES ...]] -p GENOME_PREFIX [-b BOWTIE2_PARAMS]
# [-F SAMTOOLS_FLAG_FILTER] [-mq SAMTOOLS_MAPQ] [-s SCALE] [-gq QVAL] [-gm MERGE_DISTANCE]
# [-gn DISTINCT_NINPUTS] [--trimmomatic_install_dir TRIMMOMATIC_INSTALL_DIR]
# [--picard_path PICARD_PATH] [-ofqr FASTQC_RAW_DIR] [-oft FASTQ_TRIM_DIR] [-ofqt FASTQC_TRIM_DIR]
# [-obi BOWTIE2_INDEX_DIR] [-ocs CHIPQC_SAMPLESHEET_DIR] [-ocr CHIPQC_OUT_DIR] [-omp MAPPED_DIR]
# [-omc MACS_DIR] [-ogs FINAL_GREENSCREEN] [-q]
# input_meta genome_fasta genome_gff chrom_sizes out_dir

# %% [markdown]
# # Ejecutar el pipeline

# %% [markdown]
# docker run --name GREENSCREEN \
# --platform linux/amd64 -w /home/GreenscreenProject \
# -v $PWD/GreenscreenProject:/home/GreenscreenProject \
# -i -t sklasfeld/greenscreen bash

# %% [markdown]
# root@74630fa9fc26:/home# git clone https://github.com/sklasfeld/GreenscreenProject.git

# %% [markdown]
# **root@74630fa9fc26:/home/GreenscreenProject#**
# python3 scripts/greenscreenPipeline.py \
#     -c Chr2 --genome_prefix TAIR10_Chr2 \
#     --trimmomatic_params "LEADING:3 TRAILING:3 SLIDINGWINDOW:4:15 MINLEN:36" \
#     --bowtie2_index_dir demo/meta/ArabidopsisGenome/bowtie2_genome_dir \
#     --chipqc_samplesheet_dir  demo/meta \
#     demo/meta/input_meta.csv \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2.fasta \
#     demo/meta/ArabidopsisGenome/Araport11_GFF3_genes_transposons.UPDATED.201606.Chr2.gff \
#     demo/meta/ArabidopsisGenome/TAIR10_Chr2_count.txt \
#     demo/data

# %% [markdown]
# docker cp /home/gabriel/DATOS/DATA 74630fa9fc26:/home

# %% [markdown]
# docker cp /home/gabriel/TruSeq3-PE.fa 74630fa9fc26:/home/GreenscreenProject

# %% [markdown]
# mkdir bowtie2

# %% [markdown]
#  wget --no-check-certificate "https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/735/GCF_000001735.4_TAIR10.1/GCF_000001735.4_TAIR10.1_genomic.fna.gz"

# %% [markdown]
# bowtie2-build --threads 2 GCF_000001735.4_TAIR10.1_genomic.fna bowtie2/A_thaliana_Index

# %% [markdown]
# python3 scripts/greenscreenPipeline.py \
#     --adapter_f TruSeq3-PE.fa\
#     --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" \
#     --bowtie2_index_dir bowtie2\
#     --chipqc_samplesheet_dir  DATA/ \
#     DATA/input_meta.csv \
#     Res/GCF_000001735.4_TAIR10.1_genomic.fna \
#     Res/Araport11_GFF3_genes_transposons.current.gff \
#     DATA/RESULTADOS

# %% [markdown]
# python3 scripts/greenscreenPipeline.py --adapter_f TruSeq3-PE.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir bowtie2 --chipqc_samplesheet_dir DATA DATA/input_meta.csv Res/GCF_000001735.4_TAIR10.1_genomic.fna Res/Araport11_GFF3_genes_transposons.current.gff  -p A_thaliana_Index out_dir DATA/RESULTADOS

# %% [markdown]
# ## 7/06/2023

# %% [markdown]
# Repeti los mismos pasos en XIST

# %% [markdown]
# docker run --name GREENSCREEN --platform linux/amd64 -w /home/GreenscreenProject -v $PWD/GreenscreenProject:/home/GreenscreenProject -i -t sklasfeld/greenscreen bash

# %% [markdown]
# python3 scripts/greenscreenPipeline.py --adapter_f Doc/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir Doc Doc/input_meta.csv FILES/GCF_000001735.4_TAIR10.1_genomic.fna FILES/Araport11_GFF3_genes_transposons.current.gff  -p A_thaliana_Index out_dir Doc/RESULTADOS

# %% [markdown]
# docker start GREENSCREEN

# %% [markdown]
# docker exec -it GREENSCREEN bash

# %% [markdown]
# Este comando puede funcionar para ejecutar docker en segundo plano desde apolo.

# %% [markdown]
# docker exec -it my_container python3 scripts/greenscreenPipeline.py --adapter_f Doc/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir Doc Doc/input_meta.csv FILES/GCF_000001735.4_TAIR10.1_genomic.fna FILES/Araport11_GFF3_genes_transposons.current.gff -p A_thaliana_Index out_dir Doc/RESULTADOS

# %% [markdown]
# # APOLO

# %% [markdown]
# python3 scripts/greenscreenPipeline.py --adapter_f ARCHIVOS/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir RAWDATA RAWDATA/input_meta.csv ARCHIVOS/GCF_000001735.4_TAIR10.1_genomic.fna ARCHIVOS/Araport11_GFF3_genes_transposons.current.gff  -p A_thaliana_Index out_dir RESULTADOS/

# %% [markdown]
# Lo primero que hice fue hacer un ejecutable el script en el contenedor y despues ejecute el siguinnte comando:
# **docker exec -d e15b52aff82a *python3* scripts/greenscreenPipeline.py --adapter_f ARCHIVOS/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir RAWDATA RAWDATA/input_meta.csv ARCHIVOS/GCF_000001735.4_TAIR10.1_genomic.fna ARCHIVOS/Araport11_GFF3_genes_transposons.current.gff -p A_thaliana_Index out_dir RESULTADOS/**

# %% [markdown]
# # 08/06/2023

# %% [markdown]
# screen -r my_greenscree
# docker start GREENSCREEN
# **docker exec -d e15b52aff82a python3 scripts/greenscreenPipeline.py --adapter_f ARCHIVOS/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir RAWDATA RAWDATA/input_meta.csv ARCHIVOS/GCF_000001735.4_TAIR10.1_genomic.fna ARCHIVOS/Araport11_GFF3_genes_transposons.current.gff -p A_thaliana_Index out_dir RESULTADOS/**
# docker exec -it e15b52aff82a ps aux
# AHORA SI VA A FUNCIONAR, me estaba faltando el python3, aunque no se si existan problemas de incompatibilidad. Ya lo revise y si se ejecuta con python3.

# %% [markdown]
# screen -S my_greenscreen
#
# **docker exec -d e15b52aff82a scripts/greenscreenPipeline.py --adapter_f ARCHIVOS/TruSeq3-PE-2.fa --trimmomatic_params "LEADING:3 TRAILING:20 SLIDINGWINDOW:4:15 MINLEN:36" --bowtie2_index_dir BOWTIE2 --chipqc_samplesheet_dir RAWDATA RAWDATA/input_meta.csv ARCHIVOS/GCF_000001735.4_TAIR10.1_genomic.fna ARCHIVOS/Araport11_GFF3_genes_transposons.current.gff -p A_thaliana_Index out_dir RESULTADOS/**
#
# Si necesitas volver a la sesión de screen más tarde, puedes usar el siguiente comando:
#
# screen -r mi_greenscreen

# %% [markdown]
# cree un screen y trate de correr ahi el comando en docker en segundo plano, pero no funciono

# %% [markdown]
# Pero en XIST, sigue ejecutandose y todo va bien al parecer.

# %% [markdown]
# Revisando el pipeline de bell, si voy a necesitar los fasta de los transcritos para generar los index necesarios para bowtie2.

# %% [markdown]
# Estrategia 1:
# Con el archivo de **anotacion** y el **genoma de referencia** en bedtools se pueden generar el fasta de todos los transcritos anotados, despues se generan los fasta de los transcritos que se ocupan.

# %% [markdown]
# Con el archivo de anotacion del lab, no se si vaya a tener algun problema ya que no es un gtf sino un tsv.

# %% [markdown]
# Generar el archivo bed, con el genoma de referencia y el gtf.

# %% [markdown]
# **bedtools intersect -a archivo.gtf -b genoma_referencia.fasta -s -split -bed -wa > transcritos.bed**

# %% [markdown]
# Despues generar el fasta de los transcritos anotados.

# %% [markdown]
# **bedtools getfasta -fi genoma_referencia.fasta -bed transcritos.bed -fo transcritos.fasta**

# %% [markdown]
# Y despues generar los fasta de los transcritos que se ocupan, tRNA, mRNA, etc.

# %% [markdown]
# **for PRO in three_prime_UTR five_prime_UTR exon lnc_RNA miRNA mRNA ncRNA rRNA snoRNA snRNA tRNA; do grep "^>$PRO" transcritos.fasta > $PRO.fasta; done**

# %%
# %%bash
# cd ../Dict
# bedtools intersect -a Araport11_GTF_genes_transposons.current.gtf -b nuevo_GCF_000001735.4_TAIR10.1_genomic.fna -s -split -bed -wa > transcritos.bed
# ls -lht
# Out:
# total 1.4G
# drwxr-xr-x 2 gabriel gabriel 4.0K Jun 13 00:14 BED_FILES
# -rw-r--r-- 1 gabriel gabriel  195 Jun 12 18:52 TAIR10_chr_all.fas.fai
# -rw-r--r-- 1 gabriel gabriel 576M Jun  9 00:58 Araport11_all.fasta
# -rw-r--r-- 1 gabriel gabriel  194 Jun  9 00:58 nuevo_GCF_000001735.4_TAIR10.1_genomic.fna.fai
# -rw-r--r-- 1 gabriel gabriel 116M Jun  9 00:57 nuevo_GCF_000001735.4_TAIR10.1_genomic.fna
# -rw-r--r-- 1 gabriel gabriel  244 Jun  9 00:53 GCF_000001735.4_TAIR10.1_genomic.fna.fai
# -rw-r--r-- 1 gabriel gabriel  85M May 13 13:20 Araport11_GTF_genes_transposons.current.gtf
# -rw-r--r-- 1 gabriel gabriel 116M Oct 20  2022 GCF_000001735.4_TAIR10.1_genomic.fna
# -rw-r--r-- 1 gabriel gabriel  19M Sep 15  2022 Araport11_upstream_500_2022091.fasta
# -rw-r--r-- 1 gabriel gabriel 101M Sep 15  2022 Araport11_upstream_3000_2022091.fasta
# -rw-r--r-- 1 gabriel gabriel  35M Sep 15  2022 Araport11_upstream_1000_2022091.fasta
# ...

# %% [markdown]
# Nada de lo que intente funciono, por lo que tendre que optar por una nueva estrategis, que fue lo que hizo adrian.

# %% [markdown]
# Pasar de gtf a bed.

# %%
# %%bash
# cd ../Dict
# head *.gtf
# Out:
# Chr1	Araport11	gene	3631	5899	.	+	.	transcript_id "AT1G01010"; gene_id "AT1G01010";
# Chr1	Araport11	mRNA	3631	5899	.	+	.	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	3760	3913	.	+	0	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	3996	4276	.	+	2	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	4486	4605	.	+	0	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	4706	5095	.	+	0	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	5174	5326	.	+	0	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	CDS	5439	5630	.	+	0	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	exon	3631	3913	.	+	.	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	exon	3996	4276	.	+	.	transcript_id "AT1G01010.1"; gene_id "AT1G01010";

# %% [markdown]
# **Col1** Nombre del cromosoma *COL1*
# **Col2** Posicion de inicio  *COL4*
# **Col3** Posicion de final  *COL5*
# **Col4** Nombre o identificador  *COL9*
# **Col5** Score  *COL8*
# **Col6** Strand  *COL7*

# %%
# %%bash
# cd ../Dict
# cut -f1,4,5,7,8,9 Araport11_GTF_genes_transposons.current.gtf | awk -F'\t' -v OFS='\t' '{print $1, $2, $3, $6, $5, $4}' |head
# Out:
# Chr1	3631	5899	transcript_id "AT1G01010"; gene_id "AT1G01010";	.	+
# Chr1	3631	5899	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+
# Chr1	3760	3913	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	0	+
# Chr1	3996	4276	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	2	+
# Chr1	4486	4605	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	0	+
# Chr1	4706	5095	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	0	+
# Chr1	5174	5326	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	0	+
# Chr1	5439	5630	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	0	+
# Chr1	3631	3913	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+
# Chr1	3996	4276	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+

# %%
# %%bash
# cd ../Dict
# cut -f1,4,5,7,8,9 Araport11_GTF_genes_transposons.current.gtf | awk -F'\t' -v OFS='\t' '{print $1, $2, $3, $6, $5, $4}' > Araport11.bed

# %%
# %%bash
# cd ../Dict
# bedtools getfasta -fi GCF_000001735.4_TAIR10.1_genomic.fna -bed Araport11.bed -name -fo Araport11_all.fasta

# %% [markdown]
# No funciono

# %%
# %%bash
# cd ../Dict
# sed 's/>NC_003070\.9 .*/>Chr1/
#      s/>NC_003071\.7 .*/>Chr2/
#      s/>NC_003074\.8 .*/>Chr3/
#      s/>NC_003075\.7 .*/>Chr4/
#      s/>NC_003076\.8 .*/>Chr5/
#      s/>NC_037304\.1 .*/>ChrM/
#      s/>NC_000932\.1 .*/>ChrC/' GCF_000001735.4_TAIR10.1_genomic.fna > nuevo_GCF_000001735.4_TAIR10.1_genomic.fna

# %%
# %%bash
# cd ../Dict
# bedtools getfasta -fi nuevo_GCF_000001735.4_TAIR10.1_genomic.fna -bed Araport11.bed -name -fo Araport11_all.fasta

# %%
# %%bash
# cd ../Dict
# grep ">" Araport11_all.fasta|head
# Out:
# >transcript_id "AT1G01010"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";

# %% [markdown]
# Al ver esto, no voy a poder separar por tipo, por lo que voy a tener que separar desde antes. Y ademas voy a tener que hacer pruebas.

# %% [markdown]
# # 09/06/2023

# %%
# %%bash
# cd ../Dict
# awk -F'\t' 'BEGIN{OFS="\t"} $3=="three_prime_UTR"' Araport11_GTF_genes_transposons.current.gtf|head
# Out:
# Chr1	Araport11	three_prime_UTR	5631	5899	.	+	.	transcript_id "AT1G01010.1"; gene_id "AT1G01010";
# Chr1	Araport11	three_prime_UTR	6788	6914	.	-	.	transcript_id "AT1G01020.1"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	6788	7069	.	-	.	transcript_id "AT1G01020.2"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	7157	7314	.	-	.	transcript_id "AT1G01020.2"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	6788	6914	.	-	.	transcript_id "AT1G01020.3"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	6788	6914	.	-	.	transcript_id "AT1G01020.4"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	6788	6914	.	-	.	transcript_id "AT1G01020.5"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	6788	7069	.	-	.	transcript_id "AT1G01020.6"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	7157	7314	.	-	.	transcript_id "AT1G01020.6"; gene_id "AT1G01020";
# Chr1	Araport11	three_prime_UTR	11649	11863	.	-	.	transcript_id "AT1G01030.1"; gene_id "AT1G01030";

# %%
# %%bash
# cd ../Dict
# awk -F'\t' 'BEGIN{OFS="\t"} $3=="three_prime_UTR"' Araport11_GTF_genes_transposons.current.gtf| cut -f1,4,5,7,8,9|awk -F'\t' -v OFS='\t' '{print $1, $2, $3, $6, $5, $4}'|head
# Out:
# Chr1	5631	5899	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+
# Chr1	6788	6914	transcript_id "AT1G01020.1"; gene_id "AT1G01020";	.	-
# Chr1	6788	7069	transcript_id "AT1G01020.2"; gene_id "AT1G01020";	.	-
# Chr1	7157	7314	transcript_id "AT1G01020.2"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.3"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.4"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.5"; gene_id "AT1G01020";	.	-
# Chr1	6788	7069	transcript_id "AT1G01020.6"; gene_id "AT1G01020";	.	-
# Chr1	7157	7314	transcript_id "AT1G01020.6"; gene_id "AT1G01020";	.	-
# Chr1	11649	11863	transcript_id "AT1G01030.1"; gene_id "AT1G01030";	.	-

# %% [markdown]
# El comnando fuciona correctamente, por lo que ahora se va a ingresar a un loop, para generar todos los archivos de los transcritos, que son los siguiente:
# three_prime_UTR
# five_prime_UTR
# exon
# lnc_RNA
# miRNA
# mRNA
# ncRNA
# rRNA
# snoRNA
# snRNA
# tRNA

# %%
# %%bash
# cd ../Dict
# for PRO in three_prime_UTR five_prime_UTR exon lnc_RNA miRNA mRNA ncRNA rRNA snoRNA snRNA tRNA; do awk -F'\t' -v PRO="$PRO" 'BEGIN{OFS="\t"} $3==PRO' Araport11_GTF_genes_transposons.current.gtf | cut -f1,4,5,7,8,9 | awk -F'\t' -v OFS='\t' '{print $1, $2, $3, $6, $5, $4}' | head; done
# Out:
# Chr1	5631	5899	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+
# Chr1	6788	6914	transcript_id "AT1G01020.1"; gene_id "AT1G01020";	.	-
# Chr1	6788	7069	transcript_id "AT1G01020.2"; gene_id "AT1G01020";	.	-
# Chr1	7157	7314	transcript_id "AT1G01020.2"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.3"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.4"; gene_id "AT1G01020";	.	-
# Chr1	6788	6914	transcript_id "AT1G01020.5"; gene_id "AT1G01020";	.	-
# Chr1	6788	7069	transcript_id "AT1G01020.6"; gene_id "AT1G01020";	.	-
# Chr1	7157	7314	transcript_id "AT1G01020.6"; gene_id "AT1G01020";	.	-
# Chr1	11649	11863	transcript_id "AT1G01030.1"; gene_id "AT1G01030";	.	-
# Chr1	3631	3759	transcript_id "AT1G01010.1"; gene_id "AT1G01010";	.	+
# Chr1	8667	9130	transcript_id "AT1G01020.1"; gene_id "AT1G01020";	.	-
# Chr1	8667	8737	transcript_id "AT1G01020.2"; gene_id "AT1G01020";	.	-
# Chr1	8443	8464	transcript_id "AT1G01020.3"; gene_id "AT1G01020";	.	-
# ...

# %% [markdown]
# El comando funciona correctamente, por lo que se procedera a guardar el contenido en archivos individuales

# %%
# %%bash
# cd ../Dict
# for PRO in three_prime_UTR five_prime_UTR exon lnc_RNA miRNA mRNA ncRNA rRNA snoRNA snRNA tRNA; do awk -F'\t' -v PRO="$PRO" 'BEGIN{OFS="\t"} $3==PRO' Araport11_GTF_genes_transposons.current.gtf | cut -f1,4,5,7,8,9 | awk -F'\t' -v OFS='\t' '{print $1, $2, $3, $6, $5, $4}' > "${PRO}_Araport11.bed"; done
# ls -lht
# Out:
# total 1.4G
# -rw-r--r-- 1 gabriel gabriel  51K Jun  9 09:52 tRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 6.1K Jun  9 09:52 snRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 snoRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 1.1K Jun  9 09:52 rRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 ncRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.8M Jun  9 09:52 mRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  32K Jun  9 09:52 miRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 183K Jun  9 09:52 lnc_RNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  24M Jun  9 09:52 exon_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 4.1M Jun  9 09:52 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.6M Jun  9 09:52 three_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 576M Jun  9 00:58 Araport11_all.fasta
# -rw-r--r-- 1 gabriel gabriel  194 Jun  9 00:58 nuevo_GCF_000001735.4_TAIR10.1_genomic.fna.fai
# ...

# %% [markdown]
# El comando parace funcionar correctamente.

# %%
# %%bash
# cd ../Dict
# #mkdir BED_FILES
# ls -lht
# Out:
# total 1.4G
# drwxr-xr-x 2 gabriel gabriel 4.0K Jun  9 10:14 BED_FILES
# -rw-r--r-- 1 gabriel gabriel  51K Jun  9 09:52 tRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 6.1K Jun  9 09:52 snRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 snoRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 1.1K Jun  9 09:52 rRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 ncRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.8M Jun  9 09:52 mRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  32K Jun  9 09:52 miRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 183K Jun  9 09:52 lnc_RNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  24M Jun  9 09:52 exon_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 4.1M Jun  9 09:52 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.6M Jun  9 09:52 three_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 576M Jun  9 00:58 Araport11_all.fasta
# ...

# %%
# %%bash
# cd ../Dict
# find . -type f -name "*.bed" ! -name "Araport11.bed" -exec cp {} BED_FILES \;
# Out:
# cp: './BED_FILES/tRNA_Araport11.bed' and 'BED_FILES/tRNA_Araport11.bed' are the same file
# cp: './BED_FILES/rRNA_Araport11.bed' and 'BED_FILES/rRNA_Araport11.bed' are the same file
# cp: './BED_FILES/mRNA_Araport11.bed' and 'BED_FILES/mRNA_Araport11.bed' are the same file
# cp: './BED_FILES/snoRNA_Araport11.bed' and 'BED_FILES/snoRNA_Araport11.bed' are the same file
# cp: './BED_FILES/ncRNA_Araport11.bed' and 'BED_FILES/ncRNA_Araport11.bed' are the same file
# cp: './BED_FILES/lnc_RNA_Araport11.bed' and 'BED_FILES/lnc_RNA_Araport11.bed' are the same file
# cp: './BED_FILES/three_prime_UTR_Araport11.bed' and 'BED_FILES/three_prime_UTR_Araport11.bed' are the same file
# cp: './BED_FILES/miRNA_Araport11.bed' and 'BED_FILES/miRNA_Araport11.bed' are the same file
# cp: './BED_FILES/exon_Araport11.bed' and 'BED_FILES/exon_Araport11.bed' are the same file
# cp: './BED_FILES/snRNA_Araport11.bed' and 'BED_FILES/snRNA_Araport11.bed' are the same file
# ...

# %%
# %%bash
# cd ../Dict/BED_FILES
# ls -lht
# Out:
# total 35M
# -rw-r--r-- 1 gabriel gabriel 4.1M Jun  9 10:07 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 6.1K Jun  9 10:07 snRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  24M Jun  9 10:07 exon_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  32K Jun  9 10:07 miRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.6M Jun  9 10:07 three_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 183K Jun  9 10:07 lnc_RNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 10:07 ncRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 10:07 snoRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.8M Jun  9 10:07 mRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 1.1K Jun  9 10:07 rRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  51K Jun  9 10:07 tRNA_Araport11.bed

# %%
# %%bash
# cd ../Dict/BED_FILES
# for PRO in *.bed; do bedtools getfasta -fi ../nuevo_GCF_000001735.4_TAIR10.1_genomic.fna -bed "$PRO" -name -fo "${PRO%.bed}.fasta"; done
# Out:
# Feature (Chr1:6257701-6257701) has length = 0, Skipping.
# Feature (Chr3:8680905-8680905) has length = 0, Skipping.
# Feature (Chr4:15670020-15670020) has length = 0, Skipping.
# Feature (Chr1:519036-519036) has length = 0, Skipping.
# Feature (Chr1:626917-626917) has length = 0, Skipping.
# Feature (Chr1:1345468-1345468) has length = 0, Skipping.
# Feature (Chr1:2759279-2759279) has length = 0, Skipping.
# Feature (Chr1:3753895-3753895) has length = 0, Skipping.
# Feature (Chr1:6341257-6341257) has length = 0, Skipping.
# Feature (Chr1:6468360-6468360) has length = 0, Skipping.
# Feature (Chr1:6529777-6529777) has length = 0, Skipping.
# Feature (Chr1:6529777-6529777) has length = 0, Skipping.
# Feature (Chr1:6529777-6529777) has length = 0, Skipping.
# Feature (Chr1:6529777-6529777) has length = 0, Skipping.
# Feature (Chr1:6990362-6990362) has length = 0, Skipping.
# Feature (Chr1:7826602-7826602) has length = 0, Skipping.
# ...

# %%
# %%bash
# cd ../Dict/BED_FILES
# ls -lht
# Out:
# total 308M
# -rw-r--r-- 1 gabriel gabriel   93K Jun  9 10:14 tRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   16M Jun  9 10:14 three_prime_UTR_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   19K Jun  9 10:14 snRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   45K Jun  9 10:14 snoRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   19K Jun  9 10:14 rRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  354K Jun  9 10:14 ncRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  134M Jun  9 10:14 mRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   31K Jun  9 10:14 miRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel 1023K Jun  9 10:14 lnc_RNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   13M Jun  9 10:14 five_prime_UTR_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  110M Jun  9 10:14 exon_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  4.1M Jun  9 10:07 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  6.1K Jun  9 10:07 snRNA_Araport11.bed
# ...

# %% [markdown]
# Listo ya fueron generados los fasta de los archivos:

# %%
# %%bash
# cd ../Dict/BED_FILES
# head -n 1 *.fasta
# Out:
# ==> exon_Araport11.fasta <==
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
#
# ==> five_prime_UTR_Araport11.fasta <==
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
#
# ==> lnc_RNA_Araport11.fasta <==
# >transcript_id "AT1G03987.1"; gene_id "AT1G03987";
#
# ==> miRNA_Araport11.fasta <==
# >transcript_id "AT1G01046.1"; gene_id "AT1G01046";
#
# ==> mRNA_Araport11.fasta <==
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
#
# ==> ncRNA_Araport11.fasta <==
# >transcript_id "AT1G04425.1"; gene_id "AT1G04425";
#
# ==> rRNA_Araport11.fasta <==
# >transcript_id "AT2G01010.1"; gene_id "AT2G01010";
#
# ==> snoRNA_Araport11.fasta <==
# >transcript_id "AT1G03502.1"; gene_id "AT1G03502";
#
# ==> snRNA_Araport11.fasta <==
# >transcript_id "AT1G04263.1"; gene_id "AT1G04263";
#
# ==> three_prime_UTR_Araport11.fasta <==
# >transcript_id "AT1G01010.1"; gene_id "AT1G01010";
#
# ==> tRNA_Araport11.fasta <==
# >transcript_id "AT1G01270.1"; gene_id "AT1G01270";

# %% [markdown]
# # 12/06/2023

# %% [markdown]
# Voy a realizar una prueba, con bowtie2 para ver si el encabezado no afecta.

# %%
# %%bash
# cd ../Dict/BED_FILES
# ls -lht
# Out:
# total 308M
# -rw-r--r-- 1 gabriel gabriel   93K Jun  9 10:14 tRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   16M Jun  9 10:14 three_prime_UTR_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   19K Jun  9 10:14 snRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   45K Jun  9 10:14 snoRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   19K Jun  9 10:14 rRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  354K Jun  9 10:14 ncRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  134M Jun  9 10:14 mRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   31K Jun  9 10:14 miRNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel 1023K Jun  9 10:14 lnc_RNA_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel   13M Jun  9 10:14 five_prime_UTR_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  110M Jun  9 10:14 exon_Araport11.fasta
# -rw-r--r-- 1 gabriel gabriel  4.1M Jun  9 10:07 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  6.1K Jun  9 10:07 snRNA_Araport11.bed
# ...

# %%
# %%bash
# cd ../Dict/BED_FILES
# mkdir PRUEBA
# bowtie2-build five_prime_UTR_Araport11.fasta PRUEBA/five_prime_UTR
# Out:
# Settings:
#   Output files: "PRUEBA/five_prime_UTR.*.bt2"
#   Line rate: 6 (line is 64 bytes)
#   Lines per side: 1 (side is 64 bytes)
#   Offset rate: 4 (one in 16)
#   FTable chars: 10
#   Strings: unpacked
#   Max bucket size: default
#   Max bucket size, sqrt multiplier: default
#   Max bucket size, len divisor: 4
#   Difference-cover sample period: 1024
#   Endianness: little
#   Actual local endianness: little
#   Sanity checking: disabled
#   Assertions: disabled
#   Random seed: 0
#   Sizeofs: void*:8, int:4, long:8, size_t:8
# Input files DNA, FASTA:
#   five_prime_UTR_Araport11.fasta
# Reading reference sizes
#   Time reading reference sizes: 00:00:00
# Calculating joined length
# Writing header
# Reserving space for joined string
# Joining reference sequences
#   Time to join reference sequences: 00:00:00
# bmax according to bmaxDivN setting: 2588326
# Using parameters --bmax 1941245 --dcv 1024
#   Doing ahead-of-time memory usage test
# ...

# %%
# %%bash
# cd ../Dict/BED_FILES/PRUEBA
# ls -lht
# Out:
# total 30M
# -rw-r--r-- 1 gabriel gabriel  11M Jun 12 09:55 five_prime_UTR.rev.1.bt2
# -rw-r--r-- 1 gabriel gabriel 2.5M Jun 12 09:55 five_prime_UTR.rev.2.bt2
# -rw-r--r-- 1 gabriel gabriel  11M Jun 12 09:55 five_prime_UTR.1.bt2
# -rw-r--r-- 1 gabriel gabriel 2.5M Jun 12 09:55 five_prime_UTR.2.bt2
# -rw-r--r-- 1 gabriel gabriel 495K Jun 12 09:55 five_prime_UTR.3.bt2
# -rw-r--r-- 1 gabriel gabriel 2.5M Jun 12 09:55 five_prime_UTR.4.bt2

# %% [markdown]
# Al parecer no hubo ningun problema.

# %% [markdown]
# Pero ahora con que archivos voy a trabajar:

# %% [markdown]
# **TAIR10.1**
# https://ftp.ncbi.nlm.nih.gov/genomes/all/GCF/000/001/735/GCF_000001735.4_TAIR10.1/GCF_000001735.4_TAIR10.1_genomic.fna.gz
# **ARAPORT11 GTF**
# https://www.arabidopsis.org/download_files/Genes/Araport11_genome_release/Araport11_GFF3_genes_transposons.201606.gff.gz

# %% [markdown]
# No es mejor trabajar con TAIR10?

# %% [markdown]
# Otra duda que tengo es que todo lo que hice hasta el momento solo es con los archivos del GTF, me falta el archivo TSV de la anotacion del lab, recordando que ya tengo los fasta de las secuencias up & down.

# %%
# %%bash
# cd ../Dict
# ls -lht
# Out:
# total 1.4G
# drwxr-xr-x 3 gabriel gabriel 4.0K Jun 12 09:55 BED_FILES
# -rw-r--r-- 1 gabriel gabriel  51K Jun  9 09:52 tRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 6.1K Jun  9 09:52 snRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 snoRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 1.1K Jun  9 09:52 rRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  22K Jun  9 09:52 ncRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.8M Jun  9 09:52 mRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  32K Jun  9 09:52 miRNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 183K Jun  9 09:52 lnc_RNA_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel  24M Jun  9 09:52 exon_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 4.1M Jun  9 09:52 five_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 3.6M Jun  9 09:52 three_prime_UTR_Araport11.bed
# -rw-r--r-- 1 gabriel gabriel 576M Jun  9 00:58 Araport11_all.fasta
# ...

# %% [markdown]
# El archivo TSV se ve de la siguiente forma, por lo que la estrategia a seguir sera la siguiente:

# %%
# %%bash
# cd ../Dict
# head LncRNA_Anotacion_Lab.tsv
# Out:
# chrom	chromStart	chromEnd	TranscriptID	GeneID	score	strand	thickStart	thickEnd	itemRgb	blockCount	blockSizes	blockStarts	MatureLength	CPATscore	Type	BioType	ConfidenceLevel
# Chr1	10590655	10590900	AT1G06307.1	AT1G06307	0	-	10590900	10590900	0	1	245,	0,	245	0	monoexonic	lincRNA	HC
# Chr1	10775822	10776027	AT1G06327.1	AT1G06327	0	+	10776027	10776027	0	1	205,	0,	205	0	monoexonic	lincRNA	HC
# Chr1	10775859	10776319	AT1G06333.1	AT1G06333	0	-	10776319	10776319	0	1	460,	0,	460	0.0962366543469902	monoexonic	lincRNA	HC
# Chr1	10803627	10803853	AT1G06343.1	AT1G06343	0	-	10803853	10803853	0	1	226,	0,	226	0.207456786930925	monoexonic	lincRNA	HC
# Chr1	10921834	10922072	AT1G06353.1	AT1G06353	0	-	10922072	10922072	0	1	238,	0,	238	0	monoexonic	lincRNA	HC
# Chr1	10954287	10954711	AT1G06373.1	AT1G06373	0	+	10954711	10954711	0	1	424,	0,	424	0.412322499377828	monoexonic	lincRNA	HC
# ...

# %% [markdown]
# Para generar el archivo bed:
# 1. Quitar el encabezado
# 2. Recortar las columnas 1, 2, 3, 4, 5, ., 7
# 3. Unir la columna 4 y 5 con un ;.
# 4. Generar el archivo bed.

# %% [markdown]
# Pero se va a perder la informacion del Biotype. Por lo que una posible solucion seria separarlo en los diferentes biotype, pero no lo creo.
# Ya que de todas formas se puede buscar despues para ser mas epsecificos. El otro punto es que los ncRNA del gtf se pueden unir con este archivo de anotacion para no generar mas archivos, aunque no creo que haya problema.

# %%
# %%bash
# cd ../Dict
# cut -f1,2,3,4,5,7 LncRNA_Anotacion_Lab.tsv|awk 'NR > 1'|awk -v OFS='\t' '{print $1, $2, $3, "Transcript_ID; "$4";" "Gene_ID; "$5, ".", $6}'|head
# Out:
# Chr1	10590655	10590900	Transcript_ID; AT1G06307.1;Gene_ID; AT1G06307	.	-
# Chr1	10775822	10776027	Transcript_ID; AT1G06327.1;Gene_ID; AT1G06327	.	+
# Chr1	10775859	10776319	Transcript_ID; AT1G06333.1;Gene_ID; AT1G06333	.	-
# Chr1	10803627	10803853	Transcript_ID; AT1G06343.1;Gene_ID; AT1G06343	.	-
# Chr1	10921834	10922072	Transcript_ID; AT1G06353.1;Gene_ID; AT1G06353	.	-
# Chr1	10954287	10954711	Transcript_ID; AT1G06373.1;Gene_ID; AT1G06373	.	+
# Chr1	11016491	11016886	Transcript_ID; AT1G06387.1;Gene_ID; AT1G06387	.	+
# Chr1	11061424	11061700	Transcript_ID; AT1G06403.1;Gene_ID; AT1G06403	.	-
# Chr1	11300617	11300966	Transcript_ID; AT1G06443.1;Gene_ID; AT1G06443	.	-
# Chr1	11300692	11301038	Transcript_ID; AT1G06447.1;Gene_ID; AT1G06447	.	+

# %%
# %%bash
# cd ../Dict
# cut -f1,2,3,4,5,7 LncRNA_Anotacion_Lab.tsv|awk 'NR > 1'|awk -v OFS='\t' '{print $1, $2, $3, "Transcript_ID; "$4";" "Gene_ID; "$5, ".", $6}'|cut -f4
# Out:
# Transcript_ID; AT1G06307.1;Gene_ID; AT1G06307
# Transcript_ID; AT1G06327.1;Gene_ID; AT1G06327
# Transcript_ID; AT1G06333.1;Gene_ID; AT1G06333
# Transcript_ID; AT1G06343.1;Gene_ID; AT1G06343
# Transcript_ID; AT1G06353.1;Gene_ID; AT1G06353
# Transcript_ID; AT1G06373.1;Gene_ID; AT1G06373
# Transcript_ID; AT1G06387.1;Gene_ID; AT1G06387
# Transcript_ID; AT1G06403.1;Gene_ID; AT1G06403
# Transcript_ID; AT1G06443.1;Gene_ID; AT1G06443
# Transcript_ID; AT1G06447.1;Gene_ID; AT1G06447
# Transcript_ID; AT1G06527.1;Gene_ID; AT1G06527
# Transcript_ID; AT1G06557.1;Gene_ID; AT1G06557
# Transcript_ID; AT1G06603.1;Gene_ID; AT1G06603
# Transcript_ID; AT1G06627.1;Gene_ID; AT1G06627
# Transcript_ID; AT1G06633.1;Gene_ID; AT1G06633
# Transcript_ID; AT1G06707.1;Gene_ID; AT1G06707
# Transcript_ID; AT1G06777.1;Gene_ID; AT1G06777
# Transcript_ID; AT1G06783.1;Gene_ID; AT1G06783
# Transcript_ID; AT1G34792.1;Gene_ID; AT1G34792
# Transcript_ID; AT1G34795.1;Gene_ID; AT1G34795
# ...

# %%
# %%capture
# %%bash
cd ../FASTA_TRA
for PRO in *.fasta; do bowtie2-build "$PRO" "../INDEX_BWT2_TRA/${PRO}_Index"; done

# %%
# %%capture
# %%bash
cd ../Dict/
bowtie2-build TAIR10_chr_all.fas ../INDEX_BWT2_TRA/genome_Index

# %% [markdown]
# De los archivos generados por los scripts de diego, se unen para generar solo 4 archivos:
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R2.fastq.dna
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R2.fastq.dna2
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R2.fastq.rna
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R2.fastq.rna2
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R1.fastq.dna
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R1.fastq.dna2
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R1.fastq.rna
# KO186_CKDL230008882_1A_H5HV2DSX7_L4_DEDUPER_TRIMM_R1.fastq.rna2
#
# **KO186_CKDL230008882_1A_H5HV2DSX7_L4_DNA_R1.fastq**
# **KO186_CKDL230008882_1A_H5HV2DSX7_L4_RNA_R1.fastq**
# **KO186_CKDL230008882_1A_H5HV2DSX7_L4_RNA_R2.fastq**
# **KO186_CKDL230008882_1A_H5HV2DSX7_L4_DNA_R2.fastq**

# %% [markdown]
# Estos archivos se encuentran en la siguiente ubicacion:
# .../BRASSICA/CHARSEQ/A_THALIANA/KO186/KO186_PRO_BELL

# %% [markdown]
# Script modificando los paths de

# %%
#!/bin/bash

set -o errexit

#usage: bash charseq_flypipe_SE_stranded.sh [/path/to/R01.fastq.gz] [/desired/working/path] [# of cores to use] [dirty or cleanup] [split reads location to avoid reruning bridge splitter eg /07_09_2016_dashtest/Sample1]
#NOTE: you must have super-deduper, bowtie2, and samtools in your path and python 2.7 called by python with the tools os, re, sys, bz2, time, gzip, string, argparse, and bio SeqIO

SE_READS=$1
DATAPATH=$2
CORES=$3


if [ -z "$CORES" ]
then
	echo "USAGE: bash charseq_flypipe.sh [/path/to/R01.fastq.gz] [/complete/desired/output/path/] [# of cores to use] [dirty or cleanup]"
	echo "Where the first argument is the single ended gzipped fastq file"
	echo "Second is where you would like your output files"
	echo "Third is the number of cores you'd like to use [enter 1 if you don't want to parallelize]"
	echo "Fourth is optional: type cleanup to automatically gzip intermediate files after the run to save space"
	echo ""
	echo "Test usage: bash charseq_flypipe.sh /compelete/path-to/data/cl8-test.fastq.gz /outputdirectory 4"
	exit
fi

#sanity things to ensure we can find scripts on others' machines
SOURCE="${BASH_SOURCE[0]}"
while [ -h "$SOURCE" ]; do # resolve $SOURCE until the file is no longer a symlink
  DIR="$( cd -P "$( dirname "$SOURCE" )" && pwd )"
  SOURCE="$(readlink "$SOURCE")"
  [[ $SOURCE != /* ]] && SOURCE="$DIR/$SOURCE" # if $SOURCE was a relative symlink, we need to resolve it relative to the path where the symlink file was located
done
SCRIPTDIR="$( cd -P "$( dirname "$SOURCE" )" && pwd )"

if ! type python2.7
then
	echo "Python is not an executable in your path. Please install Python 2.7 and add it to your path."
	echo "https://www.python.org/downloads/"
	exit
fi
if ! type bowtie2
then
	echo "bowtie2 is not an executable in your path. Please install bowtie2 and add it to your path."
	echo "http://bowtie-bio.sourceforge.net/bowtie2/index.shtml"
	exit
fi
if ! type samtools
then
	echo "samtools is not an executable in your path. Please install samtools and add it to your path."
	echo "http://www.htslib.org/"
	exit
fi
if ! $(python2.7 -c "import os" &> /dev/null); then
    echo "Lacking python package os"
fi
if ! $(python2.7 -c "import re" &> /dev/null); then
    echo "Lacking python package re"
fi
if ! $(python2.7 -c "import sys" &> /dev/null); then
    echo "Lacking python package sys"
fi
if ! $(python2.7 -c "import bz2" &> /dev/null); then
    echo "Lacking python package bz2"
fi
if ! $(python2.7 -c "import time" &> /dev/null); then
    echo "Lacking python package time"
fi
if ! $(python2.7 -c "import gzip" &> /dev/null); then
    echo "Lacking python package gzip"
fi
if ! $(python2.7 -c "import string" &> /dev/null); then
    echo "Lacking python package string"
fi
if ! $(python2.7 -c "import argparse" &> /dev/null); then
    echo "Lacking python package argparse"
fi
if ! $(python2.7 -c "from Bio import SeqIO" &> /dev/null); then
    echo "Lacking biopython package SeqIO"
fi
if ! $(python2.7 -c "from Bio import AlignIO" &> /dev/null); then
    echo "Lacking biopython package AlignIO"
fi
if ! $(python2.7 -c "from itertools import izip" &> /dev/null); then
    echo "Lacking python package itertools"
fi
if ! $(python2.7 -c "from optparse import OptionParser" &> /dev/null); then
    echo "Lacking python package optparse"
fi
if ! $(python2.7 -c "import os" &> /dev/null); then
    echo "Lacking python package python-levenshtein"
fi

samplefastq=${SE_READS##*/}
SAMPLE=$(echo $samplefastq | cut -f 1 -d '.')

if [ -d $DATAPATH ]
then
    echo "DATAPATH exists"
else
    mkdir $DATAPATH
fi

if [ -d $DATAPATH/$SAMPLE ] 
then
    echo "Sample directory exists."
else
    mkdir $DATAPATH/$SAMPLE
fi
cd $DATAPATH/$SAMPLE
	#->#	
	SPLIT_DNA=/mnt/HDC/gabriel/BRASSICA/CHARSEQ/A_THALIANA/KO186/KO186_PRO_BELL/KO186_CKDL230008882_1A_H5HV2DSX7_L4_DNA_R1.fastq
	#/mnt/WORK/adrian/CHAR_SEQ/BRIDGE_OLD/Dmel_imaginal_discs_paired_1_bridge.dna.bridgePE.fastq
	SPLIT_RNA=/mnt/HDC/gabriel/BRASSICA/CHARSEQ/A_THALIANA/KO186/KO186_PRO_BELL/KO186_CKDL230008882_1A_H5HV2DSX7_L4_RNA_R1.fastq
	#/mnt/WORK/adrian/CHAR_SEQ/BRIDGE_OLD/Dmel_imaginal_discs_paired_1_bridge.rna.bridgePE.fastq
	#->#

if [ -s $DATAPATH/$SAMPLE/align/bam_rev/$SAMPLE.ChARrna.tRNA.bam ];
then
	    echo "BAM files already exist"
else
	    echo "Aligning bams" $(date +"%T")
	    if [ ! -d $DATAPATH/$SAMPLE/align/ ]; then
	    mkdir $DATAPATH/$SAMPLE/align/
		fi
	    if [ ! -d $DATAPATH/$SAMPLE/align/bam ]; then
	    mkdir $DATAPATH/$SAMPLE/align/bam
	    fi
	    if [ ! -d $DATAPATH/$SAMPLE/align/unal_fwd ]; then
	    mkdir $DATAPATH/$SAMPLE/align/unal_fwd
		fi
		if [ ! -d $DATAPATH/$SAMPLE/align/bam_rev ]; then
	    mkdir $DATAPATH/$SAMPLE/align/bam_rev
		fi
	cd $DATAPATH/$SAMPLE/align
	##Align DNA to genome
	##Bowtie2
	#->#
	(bowtie2 -p$CORES -D 20 -R 3 -N 1 -L 18 -i S,1,0.50 -x /mnt/HDC/gabriel/INDEX_BWT2_TRA/genome_Index -U $SPLIT_DNA | samtools view -bS - -o $DATAPATH/$SAMPLE/align/bam/$SAMPLE.ChARdna.bam) 2>> genome_statistics.txt
	#/mnt/WORK/adrian/CHAR_SEQ/GENOME_DMEL_r6_44/genome
	(bowtie2 -p$CORES -D 20 -R 3 -N 1 -L 18 -i S,1,0.50 -x /mnt/HDC/gabriel/INDEX_BWT2_TRA/genome_Index -U $SPLIT_RNA | samtools view -bS - -o $DATAPATH/$SAMPLE/align/bam/$SAMPLE.ChARrna.genome.bam) 2>> genome_statistics.txt
	#/mnt/WORK/adrian/CHAR_SEQ/GENOME_DMEL_r6_44/genome
	#->#

	cd $DATAPATH/$SAMPLE/align
	#->#
	for genome in /mnt/HDC/gabriel/FASTA_TRA/*.fasta
	#/mnt/WORK/adrian/CHAR_SEQ/GENOME_DMEL_r6_44/*.fasta
	do
	transcriptome=$(echo $genome | cut -f 1,2 -d '.')
	transcriptome_id=$(echo $transcriptome | cut -f 3 -d '-')
	echo $transcriptome_id $SAMPLE >> transcriptome_statistics.txt
	(bowtie2 -p$CORES -D 20 -R 3 -N 1 -L 18 -i S,1,0.50 --norc --un $DATAPATH/$SAMPLE/align/unal_fwd/$transcriptome_id.fq -x $transcriptome -U $SPLIT_RNA | samtools view -bS - -o $DATAPATH/$SAMPLE/align/bam/$SAMPLE.ChARrna.$transcriptome_id.bam) 2>> transcriptome_statistics.txt
	echo  >> transcriptome_statistics.txt
	done
	#->#

	#->#
	#try again with things that didn't align forward
	cd $DATAPATH/$SAMPLE/align
	for genome in /mnt/HDC/gabriel/FASTA_TRA/*.fasta 
	#/mnt/WORK/adrian/CHAR_SEQ/GENOME_DMEL_r6_44/*.fasta
	do
	transcriptome=$(echo $genome | cut -f 1,2 -d '.')
	transcriptome_id=$(echo $transcriptome | cut -f 3 -d '-')
	echo $transcriptome_id $SAMPLE >> transcriptome_statistics.txt
	(bowtie2 -p$CORES -D 20 -R 3 -N 1 -L 18 -i S,1,0.50 --nofw -x $transcriptome -U $DATAPATH/$SAMPLE/align/unal_fwd/$transcriptome_id.fq | samtools view -bS - -o $DATAPATH/$SAMPLE/align/bam_rev/$SAMPLE.ChARrna.$transcriptome_id.bam) 2>> transcriptome_statistics.txt
	echo  >> transcriptome_statistics.txt
	done


fi
	#->#

if [ -s $DATAPATH/$SAMPLE/align/sam/$SAMPLE.ChARdna.sam ];
then
    echo "SAM files already exist"
else
    echo "Producing SAMs" $(date +"%T")
    if [ -d $DATAPATH/$SAMPLE/align/sam/ ]
    then
    cd $DATAPATH/$SAMPLE/align/sam/
    else
    mkdir $DATAPATH/$SAMPLE/align/sam_rev/
    mkdir $DATAPATH/$SAMPLE/align/sam/
    cd $DATAPATH/$SAMPLE/align/sam/
    fi
##Bams back to sams
    for file in $DATAPATH/$SAMPLE/align/bam/*.bam
    do
        fileh=${file##*/}
        samtools view -F4 $file > $DATAPATH/$SAMPLE/align/sam/${fileh/.bam/.sam}
    done
    for file in $DATAPATH/$SAMPLE/align/bam_rev/*.bam
    do 
    fileh=${file##*/}
    samtools view -F4 $file > $DATAPATH/$SAMPLE/align/sam_rev/${fileh/.bam/.sam}
    done
fi 

if [ -d $DATAPATH/$SAMPLE/newo/simple/ ]
	then
	    echo "Simplified folders already exist."
	else
	mkdir $DATAPATH/$SAMPLE/newo/
	mkdir $DATAPATH/$SAMPLE/newo/simple/
	cd $DATAPATH/$SAMPLE/newo/simple/
	##turn the sams into simple .text
	#be sure they're space deliminated
	echo "Making simple text files of read info..."
	for file in $DATAPATH/$SAMPLE/align/sam/*sam;
	do
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){1}$//g')
	awk '{if($2 == 0) sign="+"; else if ($2 == 16) sign="-"; else sign="."; print $1,$3,$4,$5,$6,length($10),sign}' $file > $DATAPATH/$SAMPLE/newo/simple/$name.simple.txt
	done

	for file in $DATAPATH/$SAMPLE/align/sam_rev/*sam;
	do
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){1}$//g')
	awk '{if($2 == 0) sign="+"; else if ($2 == 16) sign="-"; else sign="."; print $1,$3,$4,$5,$6,length($10),sign}' $file > $DATAPATH/$SAMPLE/newo/simple/$name.simple.rev.txt
	done

	#from sams aligned to genome, adds DNA adjusted coordinate
	#order of *sizeadjusted.txt: uniqueID, chrom, pos, adj pos, MAPQ, CIGAR, read length, strand on genome
	#->#
	echo "Running size_adjust to make tab delimited reads file with genome-coordinate DNA info..."
	python /mnt/HDC/gabriel/SCRIPTS/size_adjust.py $DATAPATH/$SAMPLE/newo/simple/$SAMPLE.ChARdna.simple.txt $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdna.sizeadjusted.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/size_adjust.py
	python /mnt/HDC/gabriel/SCRIPTS/size_adjust.py $DATAPATH/$SAMPLE/newo/simple/$SAMPLE.ChARrna.genome.simple.txt $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARrna.genome.sizeadjusted.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/size_adjust.py
fi
	#->#

if [ -d $DATAPATH/$SAMPLE/newo/matched/ ]
	then
	    echo "Matched folders already exist."
	else
	mkdir $DATAPATH/$SAMPLE/newo/matched
	cd $DATAPATH/$SAMPLE/newo/matched
	##Python script for add_DNA_to_transcriptome.py [rna.simple] [dna.simple] [output.simple]
	#matches DNA coordinate with RNA coordinate
	#order of *ChARdnaRna.txt: uniqueID, DNAchrom, DNApos, DNAadj pos, DNAMAPQ, DNACIGAR, DNA read length, DNA strand on genome, RNA fbgn/tr, RNApos, RNAMAPQ, RNACIGAR, RNA length of read, RNA strand on trascriptome
	echo "Adding DNA to transcriptome to make ChARdnaRna.txt files..."
	#->#

	for file in $DATAPATH/$SAMPLE/newo/simple/*rna*.simple.txt
	do
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){2}$//g')
	echo $name >> add_DNA_to_transcriptome_statistics.txt
	echo "forward RNA reads:" >> add_DNA_to_transcriptome_statistics.txt
	wc -l $file >> add_DNA_to_transcriptome_statistics.txt
	python /mnt/HDC/gabriel/SCRIPTS/add_DNA_to_transcriptome.py $file $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdna.sizeadjusted.txt $DATAPATH/$SAMPLE/newo/matched/$name.ChARdnaRna.txt >> add_DNA_to_transcriptome_statistics.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/add_DNA_to_transcriptome.py
	done

	#->#

	for file in $DATAPATH/$SAMPLE/newo/simple/*rna*.simple.rev.txt
	do
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){3}$//g')
	echo $name >> add_DNA_to_transcriptome_statistics.txt
	echo "reverse RNA reads:" >> add_DNA_to_transcriptome_statistics.txt
	wc -l $file >> add_DNA_to_transcriptome_statistics.txt
	python /mnt/HDC/gabriel/SCRIPTS/add_DNA_to_transcriptome.py $file $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdna.sizeadjusted.txt $DATAPATH/$SAMPLE/newo/matched/$name.ChARdnaRna.rev.txt >> add_DNA_to_transcriptome_statistics.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/add_DNA_to_transcriptome.py
	done

fi

if [ -d $DATAPATH/$SAMPLE/newo/matchedinfosize/ ]
	then
	    echo "Matched folders already exist."
	else
	#######
	## Python script to combine fasta info and simple files
	#usage: python add_gene_info_to_transciptome.py *ChARdnaRna.txt /genomes/dmel-all-$transcriptome-coords.dict ouputfile.info.txt
	#adds transcriptome specific information to ChARdnaRna.txt
	#order of info.txt: uniqueID, DNAchrom, DNApos, DNAadj pos, DNAMAPQ, DNACIGAR, DNA read length, DNA strand on genome, RNA fbgn/tr, RNApos, RNAMAPQ, RNACIGAR, RNA length of read, RNA strand on trascriptome, RNA type, RNA locfield, RNAchrom, RNATSS, RNATTS, RNA strand, RNA splice sites, RNA name, RNA parentgn, RNA parent, RNA length of transcript
	#rna aligned to genome is skipped because no transcriptome info 
	mkdir $DATAPATH/$SAMPLE/newo/matchedinfosize
	mkdir $DATAPATH/$SAMPLE/newo/matchedinfo/
	echo "Making infosize files by looking up transcriptome information in coords.dict file..."
	cd $DATAPATH/$SAMPLE/newo/matchedinfo/
	for file in $DATAPATH/$SAMPLE/newo/matched/*.ChARdnaRna.txt
	do
	fileh=${file##*/}
	transcriptome=$(echo $fileh | cut -f 3 -d '.')
	name=$(echo $fileh | sed -r 's/(.[^.]+){1}$//g')
	echo $name
	echo $transcriptome
	if [ "$transcriptome" = "genome" ];
	then
	        continue
	fi
	#->#
	python /mnt/HDC/gabriel/SCRIPTS/add_gene_info_to_transcriptome.py $file /mnt/HDC/gabriel/DMEL_COORDS/$transcriptome.coords.dict $DATAPATH/$SAMPLE/newo/matchedinfo/$name.info.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/add_gene_info_to_transcriptome.py ##/mnt/WORK/adrian/CHAR_SEQ/DIRECTORIO_DMEL/dmel-all-$transcriptome-r6.44.coords.dict
	done

	#->#
	#->#
	for file in $DATAPATH/$SAMPLE/newo/matched/*.ChARdnaRna.rev.txt
	do
	fileh=${file##*/}
	transcriptome=$(echo $fileh | cut -f 3 -d '.')
	name=$(echo $fileh | sed -r 's/(.[^.]+){2}$//g')
	echo $name
	echo $transcriptome
	python /mnt/HDC/gabriel/SCRIPTS/add_gene_info_to_transcriptome.py $file /mnt/HDC/gabriel/DMEL_COORDS/$transcriptome.coords.dict $DATAPATH/$SAMPLE/newo/matchedinfo/$name.info.rev.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/add_gene_info_to_transcriptome.py ##/mnt/WORK/adrian/CHAR_SEQ/DIRECTORIO_DMEL/dmel-all-$transcriptome-r6.44.coords.dict
	done

	#->#
	
	##Pyton script to add RNA adjusted position and create masterfiles
	#usage:python size_adjust_master.py *info.txt outfile.infosize.txt /raid1/lab/nteran/dmel_coords.dict/dmel-all-gene-r5.57.coords.dict
	#order of infosize.txt is same as defined in google doc masterfile
	echo "Adding genome coordinate information to RNA to make infosize file..."
	for file in $DATAPATH/$SAMPLE/newo/matchedinfo/*info.txt
	do 
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){2}$//g')
	echo $name 
	wc -l $file
	python /mnt/HDC/gabriel/SCRIPTS/size_adjust_master.py $file $DATAPATH/$SAMPLE/newo/matchedinfosize/$name.infosize.txt /mnt/HDC/gabriel/DMEL_COORDS/gene.coords.dict
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/size_adjust_master.py ##/mnt/WORK/adrian/CHAR_SEQ/DIRECTORIO_DMEL/dmel-all-gene-r6.44.coords.dict
	done

	for file in $DATAPATH/$SAMPLE/newo/matchedinfo/*info.rev.txt
	do 
	fileh=${file##*/}
	name=$(echo $fileh | sed -r 's/(.[^.]+){3}$//g')
	echo $name 
	wc -l $file
	python /mnt/HDC/gabriel/SCRIPTS/size_adjust_master.py $file $DATAPATH/$SAMPLE/newo/matchedinfosize/$name.infosize.rev.txt /mnt/HDC/gabriel/DMEL_COORDS/gene.coords.dict
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/size_adjust_master.py ##/mnt/WORK/adrian/CHAR_SEQ/DIRECTORIO_DMEL/dmel-all-gene-r6.44.coords.dict
	done
fi



##cat them all together
#work in order
#split by RNA strand alignemnt to sense or antisense of transcripts
if [ -s $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.notranscriptome.txt ]
	then
	echo "Merged file already exists"
	else
	echo "Concatenating transcriptome master files to make prioritymerged file..."
	for TRANSCRIPTOME in tRNA miscRNA ncRNA transcript three_prime_UTR five_prime_UTR exon intron miRNA gene gene_extended2000
	do
	awk '{if ($27 == "+") print $0}'  $DATAPATH/$SAMPLE/newo/matchedinfosize/$SAMPLE.ChARrna.$TRANSCRIPTOME.ChARdnaRna.infosize.txt >> $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.sense.txt
	#awk '{if ($27 == "-") print $0}'  $DATAPATH/$SAMPLE/newo/matchedinfosize/$SAMPLE.ChARrna.$TRANSCRIPTOME.ChARdnaRna.infosize.txt >> $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.antisense.txt
	awk '{if ($27 == "-") print $0}'  $DATAPATH/$SAMPLE/newo/matchedinfosize/$SAMPLE.ChARrna.$TRANSCRIPTOME.ChARdnaRna.infosize.rev.txt >> $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.antisense.txt
	done
	
	echo "Removing duplicates to make prioritized and ribominus files..."
	sort -t$'\t' -k4,4 -u $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.sense.txt > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.sense.txt
	# sort -t$'\t' -k4,4 -u $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.antisense.txt | fgrep -x -f <( awk '{print $4}' $SAMPLE.ChARdnaRna.prioritized.sense.txt) -v > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt
	
	sort -k4,4 $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.antisense.txt > $DATAPATH/$SAMPLE/newo/infanti.txt
	sort -k1,1 $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.sense.txt > $DATAPATH/$SAMPLE/newo/infsense.txt
 	python /mnt/HDC/gabriel/SCRIPTS/sortedfilter.py -i $DATAPATH/$SAMPLE/newo/infanti.txt -v $DATAPATH/$SAMPLE/newo/infsense.txt -c 4 -d 1 > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/sortedfilter.py 

	grep -v -e 'rRNA' -e 'FBgn0085813' $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.sense.txt > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.ribominus.sense.txt
	grep -v -e 'rRNA' -e 'FBgn0085813' $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.ribominus.antisense.txt
	cd $DATAPATH/$SAMPLE/
	#searches for unique IDs found in RNA aligned to genome that were not found aligned to other transcriptomes

	sort -t$'\t' -k4,4 -u $DATAPATH/$SAMPLE/newo/$SAMPLE.ChARdnaRna.prioritymerged.antisense.txt > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt
	grep -v -e 'rRNA' -e 'FBgn0085813' $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.ribominus.antisense.txt
	cd $DATAPATH/$SAMPLE/

	#searches for unique IDs found in RNA aligned to genome that were not found aligned to other transcriptomes
	#fgrep -x -f <( awk '{print $4}' $SAMPLE.ChARdnaRna.prioritized.sense.txt) -v $DATAPATH/$SAMPLE/newo/matched/$SAMPLE.ChARrna.genome.ChARdnaRna.txt | fgrep -x -f <( awk '{print $4}' $SAMPLE.ChARdnaRna.prioritized.antisense.txt) -v > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.notranscriptome.txt
	

	sort -k4,4 $DATAPATH/$SAMPLE/newo/matched/$SAMPLE.ChARrna.genome.ChARdnaRna.txt > $DATAPATH/$SAMPLE/newo/infgenome.txt
	cat $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt >> $DATAPATH/$SAMPLE/newo/infsense.txt
	sort -k1,1 $DATAPATH/$SAMPLE/newo/infsense.txt > $DATAPATH/$SAMPLE/newo/inftransc.txt
 	python /mnt/HDC/gabriel/SCRIPTS/sortedfilter.py -i $DATAPATH/$SAMPLE/newo/infgenome.txt -v $DATAPATH/$SAMPLE/newo/inftransc.txt -c 4 -d 1 > $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.notranscriptome.txt
	#/mnt/WORK/adrian/CHAR_SEQ/SCRIPTDIR_NEW/sortedfilter.py

 	rm $DATAPATH/$SAMPLE/newo/infanti.txt
 	rm $DATAPATH/$SAMPLE/newo/infsense.txt
 	rm $DATAPATH/$SAMPLE/newo/infgenome.txt
 	rm $DATAPATH/$SAMPLE/newo/inftransc.txt
	#final number of matched reads:
fi

echo "Tabulating final stats..."
echo 'Final number of matched reads' >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
echo 'sense reads'>> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
cat $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.sense.txt | wc -l >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
echo 'antisense reads' >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
cat $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.prioritized.antisense.txt | wc -l >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
echo 'Final number of ribominus reads' >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
echo 'sense reads' >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
cat $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.ribominus.sense.txt | wc -l >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
echo 'antisense reads' >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt
cat $DATAPATH/$SAMPLE/$SAMPLE.ChARdnaRna.ribominus.antisense.txt | wc -l >> $DATAPATH/$SAMPLE/$SAMPLE.summary_statistics.txt


####Possible files to clean up:
if [ $4 == "cleanup" ]
then
echo "Cleaning up SAM files and gzipping master files..."
rm $DATAPATH/$SAMPLE/align/sam/* & #these can be generated from the bam files using
gzip $DATAPATH/$SAMPLE/newo/simple/* &
gzip $DATAPATH/$SAMPLE/newo/matched/* &
gzip $DATAPATH/$SAMPLE/newo/matchedinfo/* &
echo "Finished!" $(date +"%T")
else
echo "Finished!" $(date +"%T")
fi

# %% [markdown]
# ## 13/06/2023

# %% [markdown]
# bash charseq_flypipe.sh /mnt/HDC/gabriel/BRASSICA/CHARSEQ/A_THALIANA/KO186/KO186_CKDL230008882-1A_H5HV2DSX7_L4_1.fq.gz /mnt/DB/gabriel/CHARSEQ_RESUL 3 cleanup
